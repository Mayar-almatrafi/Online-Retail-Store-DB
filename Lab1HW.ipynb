# %%
""" ميار عايض المطرفي 4453328 F2"""
# Out:
# ' ميار عايض المطرفي 4453328 F2'

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = np.zeros((200, 200))

# Object 1 square
image[30:80, 30:80] = 200

# Object 2 rectangle
image[120:170, 100:180] = 150

plt.imshow(image, cmap='gray')
plt.title("Image (2 Objects)")
plt.axis('off')
plt.show()

# %%
noise = np.random.normal(0, 20, image.shape)
noisy_image = image + noise

plt.imshow(noisy_image, cmap='gray')
plt.title("Noisy Image")
plt.show()

# %%
# Contrast stretching enhancement
min_val = noisy_image.min()
max_val = noisy_image.max()
enhanced_img = (noisy_image - min_val) / (max_val - min_val) * 255

# Denoise
denoised_img = mean_filter(enhanced_img, k=3)

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(noisy_image, cmap='gray')
plt.title("Noisy")

plt.subplot(1,3,2)
plt.imshow(enhanced_img, cmap='gray')
plt.title("Enhanced")

plt.subplot(1,3,3)
plt.imshow(denoised_img, cmap='gray')
plt.title("Denoised")

plt.show()

# %%
threshold = denoised_img.mean()
segmented = denoised_img > threshold

plt.imshow(segmented, cmap='gray')
plt.title("Segmented Objects")
plt.show()

# %%
""" mini Project short explanation
1)  Image: I created a simple image as a grid of pixel values.
2) Noise: I added random noise to mimic real capture.
3) Enhance & Denoise: I boosted the contrast and smoothed the image to reduce noise.
4) Segmentation: I used a threshold to separate the objects from the background.
"""
# Out:
# ' mini Project short explanation \n1)  Image: I created a simple image as a grid of pixel values.\n2) Noise: I added random noise to mimic real capture.\n3) Enhance & Denoise: I boosted the contrast and smoothed the image to reduce noise.\n4) Segmentation: I used a threshold to separate the objects from the background.\n'
